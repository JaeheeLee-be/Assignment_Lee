# %% [markdown]
# 안녕하세요. 수강생 여러분~! Chapter33 ~ 41 수업은 잘 들으셨나요?
#
# Chapter33 ~ 41의 수업 내용을 바탕으로 아래 문제를 풀어주시면 됩니다.
#
#
# <br>
#
#
# [**답변 입력 방법**]
#
# 문제 아래에 있는 코드 입력창에 정답코드를 작성하신 후  __▷ 버튼을 클릭해 코드를 실행__ 해보세요<br>

# %% [markdown]
# ---

# %% [markdown]
# [문제 1]
#
# 사용자로부터 두 개의 숫자를 입력받아 나눗셈을 수행하는 프로그램을 작성하세요.
#
# [예외처리]
# - 입력 값이 숫자가 아닐 때 발생할 수 있는 ValueError
# - 나누는 수가 0일 때 발생할 수 있는 ZeroDivisionError
# - 위 2가지 예외처리 후 사용자에게 이해하기 쉬운 메시지 작성 후 출력되도록 코드를 작성

# %%
try:
    x, y = map(int, input("두 개의 숫자를 입력받아 나누기를 합니다.").split(" "))
    print(f'결과값은 {x/y}입니다.')
except ValueError as exception:
    print("입력값이 정수가 아닙니다.")
    print("exception:", exception)
except Exception as exception:
    print("나누는 수가 0입니다.")
    print("exception:", exception)
# Out:
# 결과값은 0.5입니다.

# %% [markdown]
# ---

# %% [markdown]
# [문제 2]
#
# 파일을 읽어서 내용을 출력하는 프로그램을 작성하세요.
#
# - 파일이 존재하지 않을 때 발생하는 FileNotFoundError를 처리
# - 파일이 존재하지 않을 경우 "파일을 찾을 수 없습니다."라는 메시지를 출력

# %%
try:
    file = open("myfile.txt", "r")
    do = file.read()
    print(do)
    file.close
except FileNotFoundError:
    print("파일을 찾을 수 없습니다.")
# Out:
# 파일을 찾을 수 없습니다.

# %% [markdown]
# ---

# %% [markdown]
# [문제 3]
#
# 사용자로부터 여러 개의 숫자를 입력받아 리스트에 저장한 후, 사용자가 'done'이라고 입력할 때까지 계속 입력받으세요.
#
# - 입력 중 숫자가 아닌 값이 입력되면 ValueError를 처리
# - 숫자 외 값이 입력된 경우 어떤 값이 잘못 입력되었는지 사용자에게 알려주는 문구 출력<br>
#   (예: f"잘못된 값: {변수}. 숫자를 입력해주세요.")

# %%
numbers = []

while True:
    try:
        line = input("숫자만 입력해주세요. ('done' 입력시 종료):")
        if line == 'done':
            break
        numbers.append(int(line))
    except ValueError as exception:
        print(f"잘못된 값: {line} 숫자를 입력해주세요.")
        print("exception:", exception)

print("입력한 값:", numbers)
# Out:
# 잘못된 값: ㅇ 숫자를 입력해주세요.
# exception: invalid literal for int() with base 10: 'ㅇ'
# 입력한 값: [1]

# %% [markdown]
# ---

# %% [markdown]
# [문제 4]
#
# 사용자 정의 예외 NegativeNumberError를 생성하고, 사용자로부터 숫자를 입력받아 음수일 경우 NegativeNumberError를 발생시키는 프로그램을 작성하세요.
#
# - 예외 처리 구문을 사용하여 음수 입력 시 "양수를 입력해주세요."라는 메시지를 출력

# %%
class NegativeNumberError(Exception):
    pass

try:
    num = float(input("숫자를 입력해주세요: "))
    if num < 0:
        raise NegativeNumberError
    print("입력한 숫자: ", num)
except NegativeNumberError:
    print("양수를 입력해주세요.")
# Out:
# 입력한 숫자:  1.0

# %% [markdown]
# ---

# %% [markdown]
# [문제 5]
#
# datetime 모듈을 사용하여 현재 날짜와 시간을 출력하는 프로그램을 작성하세요.
#
# 또한, 사용자로부터 태어난 년도를 입력받아 현재 나이를 계산하여 출력하세요.

# %%
from datetime import datetime

now = datetime.now()
print("현재 날짜와 시간:", now)

birth_year = int(input("태어난 년도 입력해주세요.: "))
current_year = now.year
age = current_year - birth_year
print("현재 나이:", age)
# Out:
# 현재 날짜와 시간: 2026-01-13 19:34:26.118442
# 현재 나이: 26

# %% [markdown]
# ---

# %% [markdown]
# [문제 6]
#
# requests 모듈을 사용하여, 웹 페이지의 HTML을 가져오는 간단한 웹 스크레이퍼를 작성하세요.
#
# 'https://kream.co.kr/'에서<br>
# 데이터를 가져와서 상태 코드와 HTML의 첫 100자를 출력하세요.<br>
# (실습 전 requests 모듈을 설치해야 함)

# %%
import requests

url = 'https://kream.co.kr/'

response = requests.get(url)
print("상태 코드:", response.status_code)
print("HTML의 첫 100자:", response.text[:100])
# Out:
# 상태 코드: 500
# HTML의 첫 100자: <!DOCTYPE html>
# <html lang="ko">
# <head>
# <meta name="robots" content="noindex, nofollow" />
# <meta htt

# %% [markdown]
# ---

# %% [markdown]
# [문제 7]
#
# 함수 실행 시간을 측정하는 데코레이터 timer_decorator를 작성하세요.
#
# 임의의 함수가 실행되는 시간을 측정하여 "함수 실행 시간: x.xx초" 형태로 출력하세요.

# %%
import time

def timer_decorator(func):
    def wrapper(*args, **kwargs):
        start_time = time.time()
        result = func(*args, **kwargs)
        end_time = time.time()
        result_time = end_time - start_time
        print(f"함수 실행 시간: {result_time:.2f}초")
        return result
    return wrapper

@timer_decorator
def example_function():
    for _ in range(1000000):
        pass

example_function()
# Out:
# 함수 실행 시간: 0.02초

# %% [markdown]
# ---

# %% [markdown]
# [문제 8]
#
# 여러분이 자주 사용하는 수학적 연산<br>
# (예: 삼각형 넓이, 원의 넓이, 직육면체의 넓이)을 수행하는 함수들을 포함하는 mymath.py라는 이름의 모듈을 만드세요.
#
# 이 모듈을 사용하여 작성된 함수들을 실제로 임포트하고 사용하는 간단한 프로그램을 작성하세요.

# %%
import math

def triangle_area(base, height):
    return 0.5 * base * height

def circle_area(radius):
    return math.pi * radius ** 2

def prism_area(length, width, height):
    return length * width * height

# %%
from Python import mymath as my
import importlib
importlib.reload(my)

print("삼각형 넓이:", my.triangle_area(10, 8))

print("원의 넓이:", my.circle_area(5))

print("직육면체 부피:", prism_area(3, 5, 7))
# Out:
# 삼각형 넓이: 40.0
# 원의 넓이: 78.53981633974483
# 직육면체 부피: 105

# %% [markdown]
# ---

# %% [markdown]
# [문제 9]
#
# animals라는 패키지를 만들고, 이 패키지 내에 mammals, birds라는 두 개의 서브 모듈을 생성하세요.
#
# - 각 모듈에는 최소한 한 개 이상의 동물에 관한 클래스를 정의하세요<br>
#   (예: mammals에는 Dog, birds에는 Eagle)
# - 이 패키지와 모듈을 사용하여 동물들의 정보를 출력하는 프로그램을 작성
#
# 폴더 및 파일 구조
# ```
# animals/(폴더)
# ├── __init__.py
# ├── mammals.py
# └── birds.py
# ```

# %%
class Dog:
    def speak(self):
        return "멍멍!"
    def __str__(self):
        return "Dog"

# %%
class Eagle:
    def speak(self):
        return "짹!"
    def __str__(self):
        return "Eagle"

# %%
from animals.mammals import Dog
from animals.birds import Eagle

dog = Dog()
eagle = Eagle()

print(dog)
print(dog.speak())
print(eagle)
print(eagle.speak())
# Out:
# Dog
# 멍멍!
# Eagle
# 짹!

# %% [markdown]
# ---
